# %% [markdown]
# # Keyword Search

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

url = "https://abundance.it.com/get_tweets_by_search_term"
params = {
    "search_term": ["stock","stock market"],
    "or_operator": 1,
    "max_tweets": 10
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
response_json = response.json()
keyword_search = pd.DataFrame(response_json)
keyword_search_url_list = keyword_search["url"].tolist()


url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxkxvnf1cynvib9co",
	"include_errors": "true",
}
data = [
	{"url":url} for url in keyword_search_url_list
]

response = requests.post(url, headers=headers, params=params, json=data)
snapshot_id = response.json().get("snapshot_id")
print(response.json())

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

SEARCH_TERMS_X = [
    "stocks",
    "stock market",
    "investing",
    "finance stock market",
    "dividends",
    "market cap",
    "stock watchlist",
    "spx spy",
    "es spx",
    "spy qqq",
    "dia djia",
    "trading",
    "entry price",
    "profit per share",
    "elliot wave trading",
    "fastest momentum",
    "momentum system",
    "trading zone",
    "short float",
    "jerome powell",
    "rate cuts",
    "bitcoin",
    "traderinsights",
    "smallaccounttrading",
    "abnormal returns",
    "tradinglounge",
    "stockstotrade",
    "optiontrading",
    "marketsurge",
]

# url = "https://abundance.it.com/get_tweets_by_search_term"
# params = {
#     "search_term": SEARCH_TERMS_X,
#     "or_operator": 0,
#     "max_tweets": 10,
#     # "since": "2025-01-01",
#     # "until": "2025-01-05",  # YYYY-MM-DD format

# }
# auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
# response = requests.get(url, params=params, auth=auth)

def batched(iterable, n):
    """Yield successive n-sized batches from iterable."""
    for i in range(0, len(iterable), n):
        yield iterable[i:i + n]

all_results = []
for batch in batched(SEARCH_TERMS_X, 5):
    print(batch)
    response = requests.get(
        "https://abundance.it.com/get_tweets_by_search_term",
        params={
            "search_term": batch,
            "or_operator": 0,
            "max_tweets": 1 * len(batch),
        },
        auth=HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*"),
    )
    all_results += response.json()

keyword_search = pd.DataFrame(all_results)
keyword_search.to_csv("keyword_search.csv", index=False)
keyword_search.head()
# Out:
# ['stocks', 'stock market', 'investing', 'finance stock market', 'dividends']
# ['market cap', 'stock watchlist', 'spx spy', 'es spx', 'spy qqq']
# ['dia djia', 'trading', 'entry price', 'profit per share', 'elliot wave trading']
# ['fastest momentum', 'momentum system', 'trading zone', 'short float', 'jerome powell']
# ['rate cuts', 'bitcoin', 'traderinsights', 'smallaccounttrading', 'abnormal returns']
# ['tradinglounge', 'stockstotrade', 'optiontrading', 'marketsurge']
#                                                   0   \
# 0  {'type': 'tweet', 'id': '1928995618963259745',...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                   1   \
# 0  {'type': 'tweet', 'id': '1916494115556167938',...
# 1                                               None
# ...

# %%
import requests
from requests.auth import HTTPBasicAuth

url = "https://abundance.it.com/get_user_info"
params = {
    "user": "ritholtz",
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
profile_metadata = pd.DataFrame(response.json())
profile_metadata.to_csv("profile_metadata_search.csv", index=False)
profile_metadata.head()

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

url = "https://abundance.it.com/get_tweets"
params = {
    "user": "ritholtz",
    "cut_off_time": "2025-06-10",
    "max_tweets_per_user": 40,
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
print(response)
profile_search = pd.DataFrame(response.json()[0])
profile_search.to_csv("get_tweets.csv", index=False)

# %%
import requests
import pandas as pd
import time

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup200d1p0ii6d373"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

profile_search = pd.DataFrame(response_json)
profile_search.to_csv("keyword_search.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      13 response_json = {"status": "running"}
#      14 while isinstance(response_json, dict) and response_json.get("status") == "running":
# ---> 15     time.sleep(300)
#      16     response = requests.get(url, headers=headers, params=params)
#      17     response_json = response.json()
#
# KeyboardInterrupt:

# %% [markdown]
# # Profile Search

# %%
import requests

url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxmeb2u1cniijd7t4",
	"include_errors": "true",
}
data = [
	{"url":"https://x.com/elonmusk","max_number_of_posts":1},
]

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())

# %%
import requests
import pandas as pd
import time

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup2cxc2efof5uugi"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

profile_search = pd.DataFrame(response_json)
profile_search.to_csv("profile_metadata.csv", index=False)

# %% [markdown]
# # Search Profile Posts

# %%
import requests

url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxkxvnf1cynvib9co",
	"include_errors": "true",
	"type": "discover_new",
	"discover_by": "profile_url",
}
data = [
	{"url":"https://x.com/elonmusk","start_date":"06-01-2025","end_date":"06-05-2025"},
]

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())

# %%
import requests
import time
import pandas as pd

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup2ks8mycp8jafq"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

keyword_search = pd.DataFrame(response_json)
keyword_search.to_csv("profile_search.csv", index=False)
