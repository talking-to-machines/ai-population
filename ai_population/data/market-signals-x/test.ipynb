# %% [markdown]
# # Keyword Search

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

url = "https://abundance.it.com/get_tweets_by_search_term"
params = {
    "search_term": ["stock","stock market"],
    "or_operator": 1,
    "max_tweets": 10
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
response_json = response.json()
keyword_search = pd.DataFrame(response_json)
keyword_search_url_list = keyword_search["url"].tolist()


url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxkxvnf1cynvib9co",
	"include_errors": "true",
}
data = [
	{"url":url} for url in keyword_search_url_list
]

response = requests.post(url, headers=headers, params=params, json=data)
snapshot_id = response.json().get("snapshot_id")
print(response.json())

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

url = "https://abundance.it.com/get_tweets_by_search_term"
params = {
    "search_term": ["stock","harry"],
    "or_operator": 0,
    "max_tweets": 30,
    "since": "2025-01-01",
    "until": "2025-01-05",  # YYYY-MM-DD format

}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
response_json = response.json()
keyword_search = pd.DataFrame(response_json)
keyword_search.to_csv("keyword_search.csv", index=False)
keyword_search.head()
# Out:
#     type                   id  \
# 0  tweet  1875688598768611630
# 1  tweet  1875682818682216565
# 2  tweet  1875649404285403599
# 3  tweet  1875628231581429942
# 4  tweet  1875625701338181867
#
#                                                  url  \
# 0  https://x.com/HarryGaming_/status/187568859876...
# 1  https://x.com/MartsNanny/status/18756828186822...
# 2  https://x.com/case_rsrch/status/18756494042854...
# 3  https://x.com/HarryBaulsak/status/187562823158...
# 4  https://x.com/Carolewithane13/status/187562570...
#
#                                           twitterUrl  \
# 0  https://twitter.com/HarryGaming_/status/187568...
# 1  https://twitter.com/MartsNanny/status/18756828...
# 2  https://twitter.com/case_rsrch/status/18756494...
# 3  https://twitter.com/HarryBaulsak/status/187562...
# 4  https://twitter.com/Carolewithane13/status/187...
#
#                                                 text              source  \
# 0  @ElSinisterboss @ilyasWyea wth thats expensive...  Twitter for iPhone
# 1  @CarolAl38168358 @DobbieAline @unhealthytruth ...  Twitter for iPhone
# 2  Harry Markowitz was an intelligent but misguid...  Twitter for iPhone
# 3  @realDonaldTrump It's not the land and resourc...  Twitter for iPhone
# 4  @Canellelabelle Harry thought they were going ...  Twitter for iPhone
#
#    retweetCount  replyCount  likeCount  quoteCount  viewCount  \
# 0             0           0          0           0         27
# 1             0           0          0           0          4
# 2             0           0          3           0         39
# 3             0           0          0           0          9
# 4             7           8        276           0       4395
#
#                         createdAt lang  bookmarkCount  isReply  \
# 0  Sat Jan 04 23:39:45 +0000 2025   en              0     True
# 1  Sat Jan 04 23:16:47 +0000 2025   en              0     True
# 2  Sat Jan 04 21:04:00 +0000 2025   en              0    False
# 3  Sat Jan 04 19:39:52 +0000 2025   en              0     True
# 4  Sat Jan 04 19:29:49 +0000 2025   en              1     True
#
#            inReplyToId       conversationId      inReplyToUserId  \
# 0  1875688294689939692  1875687413814849635  1648036521499324452
# 1  1875677812696530950  1874896756569481647  1618196252868415488
# 2                 None  1875649404285403599                 None
# 3  1875050089305252190  1875050089305252190             25073877
# 4  1875608486152671415  1875608486152671415  1458812306348036100
#
#   inReplyToUsername                                             author  \
# 0    ElSinisterboss  {'type': 'user', 'userName': 'HarryGaming_', '...
# 1   CarolAl38168358  {'type': 'user', 'userName': 'MartsNanny', 'ur...
# 2              None  {'type': 'user', 'userName': 'case_rsrch', 'ur...
# 3   realDonaldTrump  {'type': 'user', 'userName': 'HarryBaulsak', '...
# 4    Canellelabelle  {'type': 'user', 'userName': 'Carolewithane13'...
#
#   extendedEntities  card place  \
# 0               {}  None    {}
# 1               {}  None    {}
# 2               {}  None    {}
# 3               {}  None    {}
# 4               {}  None    {}
#
#                                             entities quoted_tweet  \
# 0  {'user_mentions': [{'id_str': '164803652149932...         None
# 1  {'user_mentions': [{'id_str': '161819625286841...         None
# 2                                                 {}         None
# 3  {'user_mentions': [{'id_str': '25073877', 'ind...         None
# 4  {'user_mentions': [{'id_str': '145881230634803...         None
#
#   retweeted_tweet
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
import requests
from requests.auth import HTTPBasicAuth

url = "https://abundance.it.com/get_user_info"
params = {
    "user": "ritholtz",
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
profile_metadata = pd.DataFrame(response.json())
profile_metadata.to_csv("profile_metadata_search.csv", index=False)
profile_metadata.head()
# Out:
#          id            name  userName location                      url  \
# 0  49753604  Barry Ritholtz  Ritholtz      NYC  https://t.co/wZ6zFNkiVI
#
#                                          description  protected  isVerified  \
# 0  Chair/CIO of RWM https://t.co/St006fc1z6 Maste...      False       False
#
#    isBlueVerified verifiedType  followers  following  favouritesCount  \
# 0            True         None     230053       2739           121673
#
#    statusesCount  mediaCount                    createdAt  \
# 0         135334       17326  2009-06-22T20:27:29.000000Z
#
#                                         coverPicture  \
# 0  https://pbs.twimg.com/profile_banners/49753604...
#
#                                       profilePicture  canDm  isAutomated  \
# 0  https://pbs.twimg.com/profile_images/167889740...  False        False
#
#   automatedBy
# 0        None

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd

url = "https://abundance.it.com/get_tweets"
params = {
    "user": "ritholtz",
    "cut_off_time": "2025-06-15",
    "max_tweets_per_user": 40,
}
auth = HTTPBasicAuth("oxford", "DO$5EOYqrHoA%6y*")
response = requests.get(url, params=params, auth=auth)
print(response)
profile_search = pd.DataFrame(response.json()[0])
profile_search.to_csv("get_tweets.csv", index=False)
# Out:
# <Response [200]>

# %%
import requests
import pandas as pd
import time

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup200d1p0ii6d373"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

profile_search = pd.DataFrame(response_json)
profile_search.to_csv("keyword_search.csv", index=False)

# %% [markdown]
# # Profile Search

# %%
import requests

url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxmeb2u1cniijd7t4",
	"include_errors": "true",
}
data = [
	{"url":"https://x.com/elonmusk","max_number_of_posts":1},
]

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())

# %%
import requests
import pandas as pd
import time

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup2cxc2efof5uugi"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

profile_search = pd.DataFrame(response_json)
profile_search.to_csv("profile_metadata.csv", index=False)

# %% [markdown]
# # Search Profile Posts

# %%
import requests

url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_lwxkxvnf1cynvib9co",
	"include_errors": "true",
	"type": "discover_new",
	"discover_by": "profile_url",
}
data = [
	{"url":"https://x.com/elonmusk","start_date":"06-01-2025","end_date":"06-05-2025"},
]

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())

# %%
import requests
import time
import pandas as pd

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mbup2ks8mycp8jafq"
headers = {
	"Authorization": "Bearer 7effc080-0480-4f16-b916-fb435fc0a508",
}
params = {
	"format": "json",
}

response_json = {"status": "running"}
while isinstance(response_json, dict) and response_json.get("status") == "running":
    time.sleep(300)
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

keyword_search = pd.DataFrame(response_json)
keyword_search.to_csv("profile_search.csv", index=False)
